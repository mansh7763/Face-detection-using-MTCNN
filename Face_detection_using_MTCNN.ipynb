# %% [markdown]
# <a href="https://colab.research.google.com/github/mansh7763/Face-detection-using-MTCNN/blob/main/Face_detection_using_MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (2.15.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.25.2)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
from mtcnn import MTCNN
import cv2
from google.colab.patches import cv2_imshow

detector = MTCNN()

img = cv2.imread('/content/istockphoto-1346125184-612x612.jpg')

output = detector.detect_faces(img)
#[{},{}...{}]
print(output)

for i in output:
    x,y,widht,height = i['box']

    left_eyeX,left_eyeY = i['keypoints']['left_eye']
    right_eyeX,right_eyeY = i['keypoints']['right_eye']
    noseX,noseY = i['keypoints']['nose']
    mouth_leftX,mouth_leftY = i['keypoints']['mouth_left']
    mouth_rightX,mouth_rightY = i['keypoints']['mouth_right']


    cv2.circle(img,center=(left_eyeX,left_eyeY),color=(255,0,0),thickness=3,radius=2)
    cv2.circle(img,center=(right_eyeX,right_eyeY),color=(255,0,0),thickness=3,radius=2)
    cv2.circle(img,center=(noseX,noseY),color=(255,0,0),thickness=3,radius=2)
    cv2.circle(img,center=(mouth_leftX,mouth_leftY),color=(255,0,0),thickness=3,radius=2)
    cv2.circle(img,center=(mouth_rightX,mouth_rightY),color=(255,0,0),thickness=3,radius=2)

    cv2.rectangle(img,pt1=(x,y),pt2=(x+widht,y+height),color=(255,0,0),thickness=3)
cv2_imshow(img)

cv2.waitKey(0)
# Out:
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 7/7 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 175ms/step
# [{'box': [227, 97, 39, 50], 'confidence': 0.999936580657959, 'keypoints': {'left_eye': (239, 114), 'right_eye': (257, 117), 'nose': (247, 125), 'mouth_left': (235, 131), 'mouth_right': (254, 136)}}, {'box': [398, 89, 40, 53], 'confidence': 0.9999350905418396, 'keypoints': {'left_eye': (410, 107), 'right_eye': (429, 111), 'nose': (418, 120), 'mouth_left': (406, 125), 'mouth_right': (426, 129)}}, {'box': [461, 77, 48, 65], 'confidence': 0.9998284578323364, 'keypoints': {'left_eye': (471, 102), 'right_eye': (495, 103), 'nose': (480, 116), 'mouth_left': (471, 124), 'mouth_right': (495, 126)}}, {'box': [81, 81, 47, 59], 'confidence': 0.999800443649292, 'keypoints': {'left_eye': (95, 102), 'right_eye': (116, 103), 'nose': (107, 111), 'mouth_left': (95, 122), 'mouth_right': (116, 124)}}, {'box': [539, 65, 48, 60], 'confidence': 0.9993881583213806, 'keypoints': {'left_eye': (552, 89), 'right_eye': (573, 88), 'nose': (563, 102), 'mouth_left': (554, 111), 'mouth_right': (575, 109)}}, {'box': [17, 48, 57, 75], 'confidence': 0.9971441030502319, 'keypoints': {'left_eye': (35, 78), 'right_eye': (61, 77), 'nose': (51, 92), 'mouth_left': (36, 104), 'mouth_right': (62, 103)}}, {'box': [306, 70, 50, 65], 'confidence': 0.9966827630996704, 'keypoints': {'left_eye': (319, 95), 'right_eye': (342, 94), 'nose': (330, 108), 'mouth_left': (318, 117), 'mouth_right': (343, 117)}}, {'box': [154, 83, 52, 67], 'confidence': 0.9929792284965515, 'keypoints': {'left_eye': (171, 108), 'right_eye': (194, 114), 'nose': (180, 124), 'mouth_left': (165, 129), 'mouth_right': (190, 135)}}]
# <PIL.Image.Image image mode=RGB size=612x408>
# -1
